# %% [markdown]
# # Data Input and Output
#
# This notebook is the reference code for getting input and output, pandas can read a variety of file types using its pd.read_ methods. Let's take a look at the most common data types:

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Seoul Population by Neighborhood
#
# ###  Neighborhood is a smallest administrative division in South Korea)

# %%
df = pd.read_csv('1803.csv')

# column list
df.columns

# fix wrong column assignment
df.columns = ['시간대구분', '행정동코드', '총생활인구수', '남자0세부터9세생활인구수', '남자10세부터14세생활인구수',
       '남자15세부터19세생활인구수', '남자20세부터24세생활인구수', '남자25세부터29세생활인구수',
       '남자30세부터34세생활인구수', '남자35세부터39세생활인구수', '남자40세부터44세생활인구수',
       '남자45세부터49세생활인구수', '남자50세부터54세생활인구수', '남자55세부터59세생활인구수',
       '남자60세부터64세생활인구수', '남자65세부터69세생활인구수', '남자70세이상생활인구수', '여자0세부터9세생활인구수',
       '여자10세부터14세생활인구수', '여자15세부터19세생활인구수', '여자20세부터24세생활인구수',
       '여자25세부터29세생활인구수', '여자30세부터34세생활인구수', '여자35세부터39세생활인구수',
       '여자40세부터44세생활인구수', '여자45세부터49세생활인구수', '여자50세부터54세생활인구수',
       '여자55세부터59세생활인구수', '여자60세부터64세생활인구수', '여자65세부터69세생활인구수',
       '여자70세이상생활인구수', 'dummy']


# Set index name 
# df.index.name = '기준일'


# Set new index 
# df_indexd = df.reset_index()


# choose columns to show 
df_choose_fields = df_indexd[['시간대구분', '행정동코드', '총생활인구수', '남자20세부터24세생활인구수', '남자25세부터29세생활인구수',
       '남자30세부터34세생활인구수', '남자35세부터39세생활인구수']]


# Add new field 
# df_choose_fields['남자20세부터24세생활인구수']
# df_choose_fields['sum'] = df_choose_fields['남자20세부터24세생활인구수'] + df_choose_fields['남자25세부터29세생활인구수'] + df_choose_fields['남자30세부터34세생활인구수'] + df_choose_fields['남자35세부터39세생활인구수'] 
# df_choose_fields.loc[:, 'sum'] = df_choose_fields['남자20세부터24세생활인구수'] + df_choose_fields['남자25세부터29세생활인구수'] + df_choose_fields['남자30세부터34세생활인구수'] + df_choose_fields['남자35세부터39세생활인구수'] 


# Order columns 
# newdf.sort_values(by=[ '행정동코드', '시간대구분'], ascending=[True, False])


# DataFrame columns are Series when you pull them out, which you can then call .tolist() on to turn them into a Python list chage the order of columns - cols = newdf.columns.tolist()


# select only 기준일', '시간대구분', '행정동코드', '총생활인구수', '행정동코드1', 'sum'
# new_df_index = df_index[['기준일', '시간대구분', '총생활인구수', '행정동코드1', 'sum']]

# No decimals 
# new_df_index.round(0) 


# Grouping 
# by_comp = new_df_index.groupby("행정동코드1")
# by_comp.describe()

# Export to a file 
# new_by_comp.to_csv('new_by_comp',index=False)


# make a series obj into str type 
# df_index['행정동코드1'] = df_index.행정동코드.apply(str)
# Out:
# Index(['기준일ID', '시간대구분', '행정동코드', '총생활인구수', '남자0세부터9세생활인구수', '남자10세부터14세생활인구수',
#        '남자15세부터19세생활인구수', '남자20세부터24세생활인구수', '남자25세부터29세생활인구수',
#        '남자30세부터34세생활인구수', '남자35세부터39세생활인구수', '남자40세부터44세생활인구수',
#        '남자45세부터49세생활인구수', '남자50세부터54세생활인구수', '남자55세부터59세생활인구수',
#        '남자60세부터64세생활인구수', '남자65세부터69세생활인구수', '남자70세이상생활인구수', '여자0세부터9세생활인구수',
#        '여자10세부터14세생활인구수', '여자15세부터19세생활인구수', '여자20세부터24세생활인구수',
#        '여자25세부터29세생활인구수', '여자30세부터34세생활인구수', '여자35세부터39세생활인구수',
#        '여자40세부터44세생활인구수', '여자45세부터49세생활인구수', '여자50세부터54세생활인구수',
#        '여자55세부터59세생활인구수', '여자60세부터64세생활인구수', '여자65세부터69세생활인구수',
#        '여자70세이상생활인구수'],
#       dtype='object')

# %%
code = pd.read_excel('code.xlsx')
code.drop('통계청행정동코드',axis=1,inplace=True)
code.drop(axis = 0, index=0, inplace=True)

code1 = code.rename(columns={'행자부행정동코드': '행정동코드'})
code1['행정동코드1'] = code1.행정동코드.apply(str)

# %%
# newdf.merge(left1,right1,how='outer',on='key')
# .columns
# combined1 = combined[['행정동코드', '시도명', '시군구명', '행정동명', '기준일', '시간대구분', '총생활인구수', '남자20세부터24세생활인구수', '남자25세부터29세생활인구수','남자30세부터34세생활인구수', '남자35세부터39세생활인구수']]
# .sort_values(by=[ '행정동코드', '시간대구분'], ascending=[True, False])

combined = pd.merge(new_by_comp,code1,how='inner', on=['행정동코드1'])
combined

## daily 요일 
## hourly 07 ~ 22  

## sum top 10% 
##
# Out:
#        행정동코드1         기준일  시간대구분         총생활인구수           sum     행정동코드 시도명  \
# 0    11110690  20180316.0   11.5    4735.490122    632.520395  11110690  서울
# 1    11410655  20180316.0   11.5    6263.245076    696.431424  11410655  서울
# 2    11110570  20180316.0   11.5    7406.366237    726.770352  11110570  서울
# 3    11740690  20180316.0   11.5    6386.538193    735.085152  11740690  서울
# 4    11470610  20180316.0   11.5    6301.009903    753.269165  11470610  서울
# 5    11560660  20180316.0   11.5    5986.097267    792.294245  11560660  서울
# 6    11110700  20180316.0   11.5    7265.627539   1027.468080  11110700  서울
# 7    11110580  20180316.0   11.5    9150.236454   1052.917765  11110580  서울
# 8    11560670  20180316.0   11.5    8575.282745   1151.685168  11560670  서울
# 9    11710720  20180316.0   11.5   11414.123725   1181.631498  11710720  서울
# 10   11140680  20180316.0   11.5    7550.999587   1187.377931  11140680  서울
# ...

# %% [markdown]
# ### CSV Output

# %%
df.to_csv('example',index=False)

# %% [markdown]
# ## Excel
# Pandas can read and write excel files, keep in mind, this only imports data. Not formulas or images, having images or macros may cause this read_excel method to crash.

# %% [markdown]
# ### Excel Input

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
code = pd.read_excel('code.xlsx')
code
# Out:
#       통계청행정동코드  행자부행정동코드    시도명   시군구명         행정동명
# 0    H_SDNG_CD  H_DNG_CD  DO_NM  CT_NM     H_DNG_NM
# 1      1101053  11110530     서울    종로구          사직동
# 2      1101054  11110540     서울    종로구          삼청동
# 3      1101055  11110550     서울    종로구          부암동
# 4      1101056  11110560     서울    종로구          평창동
# 5      1101057  11110570     서울    종로구          무악동
# 6      1101058  11110580     서울    종로구          교남동
# 7      1101060  11110600     서울    종로구          가회동
# 8      1101061  11110615     서울    종로구  종로1.2.3.4가동
# 9      1101063  11110630     서울    종로구      종로5.6가동
# 10     1101064  11110640     서울    종로구          이화동
# 11     1101067  11110670     서울    종로구         창신1동
# 12     1101068  11110680     서울    종로구         창신2동
# 13     1101069  11110690     서울    종로구         창신3동
# 14     1101070  11110700     서울    종로구         숭인1동
# 15     1101071  11110710     서울    종로구         숭인2동
# 16     1101072  11110515     서울    종로구        청운효자동
# ...

# %% [markdown]
# ### Excel Output

# %%
df.to_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %% [markdown]
# ## HTML
#
# You may need to install htmllib5,lxml, and BeautifulSoup4. In your terminal/command prompt run:
#
#     conda install lxml
#     conda install html5lib
#     conda install BeautifulSoup4
#
# Then restart Jupyter Notebook.
# (or use pip install if you aren't using the Anaconda Distribution)
#
# Pandas can read table tabs off of html. For example:

# %% [markdown]
# ### HTML Input
#
# Pandas read_html function will read tables off of a webpage and return a list of DataFrame objects:

# %%
df = pd.read_html('http://www.fdic.gov/bank/individual/failed/banklist.html')

# %%
df[0]
# Out:
#                                       Bank Name             City  ST   CERT  \
# 0                        First CornerStone Bank  King of Prussia  PA  35312
# 1                            Trust Company Bank          Memphis  TN   9956
# 2                    North Milwaukee State Bank        Milwaukee  WI  20364
# 3                        Hometown National Bank         Longview  WA  35156
# 4                           The Bank of Georgia   Peachtree City  GA  35259
# 5                                  Premier Bank           Denver  CO  34112
# 6                                Edgebrook Bank          Chicago  IL  57772
# 7                          Doral BankEn Espanol         San Juan  PR  32102
# 8             Capitol City Bank & Trust Company          Atlanta  GA  33938
# 9                       Highland Community Bank          Chicago  IL  20290
# 10             First National Bank of Crestview        Crestview  FL  17557
# ...

# %% [markdown]
# ____

# %% [markdown]
# _____
# _____
# # SQL (Optional)
#
# * Note: If you are completely unfamiliar with SQL you can check out my other course: "Complete SQL Bootcamp" to learn SQL.

# %% [markdown]
# The pandas.io.sql module provides a collection of query wrappers to both facilitate data retrieval and to reduce dependency on DB-specific API. Database abstraction is provided by SQLAlchemy if installed. In addition you will need a driver library for your database. Examples of such drivers are psycopg2 for PostgreSQL or pymysql for MySQL. For SQLite this is included in Python’s standard library by default. You can find an overview of supported drivers for each SQL dialect in the SQLAlchemy docs.
#
#
# If SQLAlchemy is not installed, a fallback is only provided for sqlite (and for mysql for backwards compatibility, but this is deprecated and will be removed in a future version). This mode requires a Python database adapter which respect the Python DB-API.
#
# See also some cookbook examples for some advanced strategies.
#
# The key functions are:
#
# * read_sql_table(table_name, con[, schema, ...])
#     * Read SQL database table into a DataFrame.
# * read_sql_query(sql, con[, index_col, ...])
#     * Read SQL query into a DataFrame.
# * read_sql(sql, con[, index_col, ...])
#     * Read SQL query or database table into a DataFrame.
# * DataFrame.to_sql(name, con[, flavor, ...])
#     * Write records stored in a DataFrame to a SQL database.

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('sqlite:///:memory:')

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15
